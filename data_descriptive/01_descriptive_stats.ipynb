# %% [markdown]
# To Do:
#
# Model of death

# %% [markdown]
# # Descriptive stats for South West hospitals

# %%
import pandas as pd

# %%
sw = pd.read_csv('stroke_teams.csv', index_col=False)

# %%
# List of stroke teams
sw = list(sw.squeeze().values)

# %%
sw_dic = {
    'Royal Cornwall Hospital': 'SW1',
    'Royal Devon and Exeter Hospital': 'SW2',
    'North Devon District Hospital': 'SW3',
    'Torbay Hospital': 'SW4',
    'Musgrove Park Hospital': 'SW5',
    'Yeovil District Hospital': 'SW6'
}

# sw = list(sw_dic.keys())

# Read in the data
data_all = pd.read_csv('~/ssnap_data/data.csv')

key_results = pd.DataFrame()

# %%
years_covered = sorted(list(set(data_all['year'])))
all_years_str = f'{years_covered[0]} to {years_covered[-1]}'

# %%
# # Limit data to years 2021 to 2021
# data_all = data_all[(data_all['year'] >= 2021)
#                     & (data_all['year'] <= 2021)]

# Limit data to out of hopsital onset arriving by ambulance only
data_all = data_all[data_all['onset-to-arrival time'] > 0]
data_all = data_all[data_all['arrive by ambulance'] == True]

# Add new fields
data_all['count'] = 1
data_all['prestroke mrs 0-2'] = data_all['prior disability'] <= 2
data_all['mrs 5-6'] = data_all['discharge disability'] >= 5
data_all['mrs 0-2'] = data_all['discharge disability'] <= 2

# %% [markdown]
# Restrict fields

# %%
required_fields: list = [
    'count', 'stroke team', 'age', 'male', 'infarction', 'stroke severity',
    'onset-to-arrival time', 'onset known', 'precise onset known',
    'onset during sleep', 'arrive by ambulance', 'year',
    'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2',
    'arrival-to-scan time', 'thrombolysis',
    'scan-to-thrombolysis time', 'death', 'discharge disability', 'mrs 5-6', 'mrs 0-2'
]

data_all = data_all[required_fields]
mask = (data_all['onset known'] == True) & (
    data_all['onset-to-arrival time'] <= 240)
data_all['arrive in 4  hours'] = mask

# Add change in disability
data_all['increased disability due to stroke'] = data_all['discharge disability'] - data_all['prior disability']

# %%
summary_stats_dict = {
    'count': 'sum',
    'stroke team': 'none',
    'age': 'mean',
    'male': 'mean',
    'infarction': 'mean',
    'stroke severity': 'mean',
    'onset-to-arrival time': 'median',
    'onset known': 'mean',
    'arrive in 4  hours': 'mean',
    'precise onset known': 'mean',
    'onset during sleep': 'mean',
    'year': 'none',
    'use of AF anticoagulants': 'mean',
    'prior disability': 'mean',
    'prestroke mrs 0-2': 'mean',
    'arrival-to-scan time':     'median',
    'thrombolysis':     'mean',
    'scan-to-thrombolysis time': 'median',
    'death': 'mean',
    'discharge disability': 'mean',
    'increased disability due to stroke': 'mean',
    'mrs 5-6': 'mean',
    'mrs 0-2': 'mean'
}

# %%
summary_stats = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_all
    else:
        data = data_all[(
            (data_all['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'all E+W'
    results['year'] = year
    summary_stats[f'all E+W ({year})'] = results

# %%
for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_all[data_all['stroke team'] == hospital]
        else:
            data = data_all[(
            (data_all['stroke team'] == hospital) &
            (data_all['year'] == year)
            )]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats[f'{hospital} ({year})'] = results

# %%
summary_stats_df = pd.DataFrame(summary_stats)
# summary_stats_df.rename(sw_dic, axis=1, inplace = True)

# Only keep hospitals with more than 100 admissions:
mask_count = summary_stats_df.loc['count'] > 100
summary_stats_df = summary_stats_df.T[mask_count].T

# %%
key_results['onset known'] = summary_stats_df.loc['onset known']
key_results['arrive in 4 hours'] = summary_stats_df.loc['arrive in 4  hours']
key_results['thrombolysis all arrivals'] = summary_stats_df.loc['thrombolysis']


summary_stats_df.round(3)
# Out:
#                                    all E+W (2016 to 2021) all E+W (2016)  \
# count                                              283946          45925
# age                                             75.570672      75.797768
# male                                             0.514584       0.505041
# infarction                                       0.865179       0.864888
# stroke severity                                  8.086298       8.103756
# onset-to-arrival time                               331.0          308.0
# onset known                                      0.705057       0.694567
# arrive in 4  hours                               0.436868       0.450822
# precise onset known                              0.361167        0.36614
# onset during sleep                               0.136959       0.133348
# use of AF anticoagulants                         0.140808       0.102667
# prior disability                                 1.157981       1.128492
# prestroke mrs 0-2                                0.780307       0.781688
# arrival-to-scan time                                 42.0           48.0
# thrombolysis                                     0.134022         0.1357
# scan-to-thrombolysis time                            30.0           30.0
# death                                             0.16769       0.176375
# discharge disability                             2.918881       2.926085
# increased disability due to stroke                1.76026       1.795867
# mrs 5-6                                           0.23514       0.245008
# mrs 0-2                                            0.4569       0.454458
# stroke_team                                       all E+W        all E+W
# year                                         2016 to 2021           2016
#
#                                    all E+W (2017) all E+W (2018)  \
# count                                       47145          46137
# age                                     75.855711      75.719217
# male                                      0.50508       0.514576
# infarction                               0.867176       0.865531
# stroke severity                          8.259943       8.247979
# onset-to-arrival time                       318.0          316.0
# onset known                              0.694941       0.706786
# arrive in 4  hours                       0.447343       0.446063
# precise onset known                      0.367017       0.369378
# onset during sleep                       0.139951       0.137222
# use of AF anticoagulants                 0.116704       0.147365
# prior disability                         1.148414       1.184342
# prestroke mrs 0-2                        0.780486       0.775755
# arrival-to-scan time                         43.0           42.0
# thrombolysis                             0.136727       0.138024
# scan-to-thrombolysis time                    30.0           29.0
# death                                    0.173232       0.169712
# discharge disability                     2.916094       2.916607
# increased disability due to stroke       1.766917       1.732106
# mrs 5-6                                  0.241489       0.240306
# mrs 0-2                                   0.45621       0.460173
# stroke_team                               all E+W        all E+W
# year                                         2017           2018
#
#                                    all E+W (2019) all E+W (2020)  \
# count                                       46793          47224
# age                                     75.802951      75.159347
# male                                     0.513773       0.520011
# infarction                               0.861817       0.866487
# stroke severity                          8.177334       7.926055
# onset-to-arrival time                       319.0          350.0
# onset known                              0.718975        0.70714
# arrive in 4  hours                       0.442075       0.425335
# precise onset known                      0.363281       0.354015
# onset during sleep                       0.138739       0.139357
# use of AF anticoagulants                 0.156925       0.156742
# prior disability                         1.190499       1.139632
# prestroke mrs 0-2                        0.772765       0.787248
# arrival-to-scan time                         40.0           41.0
# thrombolysis                             0.139743       0.128621
# scan-to-thrombolysis time                    30.0           32.0
# death                                    0.172163       0.158203
# discharge disability                     2.934428       2.880702
# increased disability due to stroke       1.743289       1.740936
# mrs 5-6                                  0.236232       0.221942
# mrs 0-2                                  0.457782       0.462773
# stroke_team                               all E+W        all E+W
# year                                         2019           2020
#
#                                    all E+W (2021)  \
# count                                       50722
# age                                      75.13367
# male                                     0.527759
# infarction                               0.865147
# stroke severity                          7.827235
# onset-to-arrival time                       370.0
# onset known                              0.707602
# arrive in 4  hours                        0.41207
# precise onset known                      0.348468
# onset during sleep                       0.133335
# use of AF anticoagulants                  0.16208
# prior disability                         1.156678
# prestroke mrs 0-2                        0.783526
# arrival-to-scan time                         40.0
# thrombolysis                             0.126099
# scan-to-thrombolysis time                    32.0
# death                                    0.157545
# discharge disability                     2.938146
# increased disability due to stroke       1.781071
# mrs 5-6                                  0.226884
# mrs 0-2                                  0.450495
# stroke_team                               all E+W
# year                                         2021
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016 to 2021)  \
# count                                                                            2056
# age                                                                         74.229086
# male                                                                         0.537451
# infarction                                                                    0.85749
# stroke severity                                                              7.452821
# onset-to-arrival time                                                           270.0
# onset known                                                                  0.807393
# arrive in 4  hours                                                           0.473249
# precise onset known                                                          0.459144
# onset during sleep                                                           0.192607
# use of AF anticoagulants                                                     0.108949
# prior disability                                                             1.180934
# prestroke mrs 0-2                                                            0.795233
# arrival-to-scan time                                                             49.0
# thrombolysis                                                                  0.14251
# scan-to-thrombolysis time                                                        23.0
# death                                                                        0.148833
# discharge disability                                                         2.750123
# increased disability due to stroke                                           1.574865
# mrs 5-6                                                                      0.210117
# mrs 0-2                                                                      0.531615
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                     2016 to 2021
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016)  \
# count                                                                             389
# age                                                                         74.993573
# male                                                                         0.562982
# infarction                                                                   0.843188
# stroke severity                                                              6.933162
# onset-to-arrival time                                                           273.0
# onset known                                                                  0.799486
# arrive in 4  hours                                                           0.473008
# precise onset known                                                          0.529563
# onset during sleep                                                            0.18509
# use of AF anticoagulants                                                     0.064267
# prior disability                                                               1.1491
# prestroke mrs 0-2                                                            0.804627
# arrival-to-scan time                                                             51.0
# thrombolysis                                                                  0.14653
# scan-to-thrombolysis time                                                        20.0
# death                                                                        0.125964
# discharge disability                                                         2.679587
# increased disability due to stroke                                             1.5323
# mrs 5-6                                                                      0.182519
# mrs 0-2                                                                      0.524422
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                             2016
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2017)  \
# count                                                                             309
# age                                                                         74.635922
# male                                                                         0.579288
# infarction                                                                   0.883495
# stroke severity                                                              7.142395
# onset-to-arrival time                                                           297.0
# onset known                                                                  0.786408
# arrive in 4  hours                                                           0.466019
# precise onset known                                                          0.427184
# onset during sleep                                                           0.216828
# use of AF anticoagulants                                                     0.084142
# prior disability                                                             1.148867
# prestroke mrs 0-2                                                            0.812298
# arrival-to-scan time                                                             52.0
# thrombolysis                                                                 0.113269
# scan-to-thrombolysis time                                                        29.0
# death                                                                        0.119741
# discharge disability                                                         2.651316
# increased disability due to stroke                                           1.526316
# mrs 5-6                                                                      0.200647
# mrs 0-2                                                                      0.530744
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                             2017
#
#                                     ...  \
# count                               ...
# age                                 ...
# male                                ...
# infarction                          ...
# stroke severity                     ...
# onset-to-arrival time               ...
# onset known                         ...
# arrive in 4  hours                  ...
# precise onset known                 ...
# onset during sleep                  ...
# use of AF anticoagulants            ...
# prior disability                    ...
# prestroke mrs 0-2                   ...
# arrival-to-scan time                ...
# thrombolysis                        ...
# scan-to-thrombolysis time           ...
# death                               ...
# discharge disability                ...
# increased disability due to stroke  ...
# mrs 5-6                             ...
# mrs 0-2                             ...
# stroke_team                         ...
# year                                ...
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# count                                                                            1222
# age                                                                         73.854337
# male                                                                         0.487725
# infarction                                                                   0.855974
# stroke severity                                                              9.013912
# onset-to-arrival time                                                           460.0
# onset known                                                                  0.574468
# arrive in 4  hours                                                           0.373977
# precise onset known                                                          0.017185
# onset during sleep                                                            0.00491
# use of AF anticoagulants                                                     0.148936
# prior disability                                                             0.417349
# prestroke mrs 0-2                                                            0.925532
# arrival-to-scan time                                                             43.0
# thrombolysis                                                                 0.157119
# scan-to-thrombolysis time                                                        28.0
# death                                                                        0.165303
# discharge disability                                                         2.995045
# increased disability due to stroke                                           2.573906
# mrs 5-6                                                                      0.212766
# mrs 0-2                                                                       0.42635
# stroke_team                                       Queen's Medical Centre - Nottingham
# year                                                                     2016 to 2021
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# count                                                                     254
# age                                                                 74.488189
# male                                                                 0.480315
# infarction                                                           0.893701
# stroke severity                                                      9.283465
# onset-to-arrival time                                                   214.0
# onset known                                                          0.708661
# arrive in 4  hours                                                   0.519685
# precise onset known                                                  0.015748
# onset during sleep                                                   0.003937
# use of AF anticoagulants                                             0.137795
# prior disability                                                     0.464567
# prestroke mrs 0-2                                                    0.917323
# arrival-to-scan time                                                     33.0
# thrombolysis                                                         0.200787
# scan-to-thrombolysis time                                                30.0
# death                                                                0.200787
# discharge disability                                                 3.173228
# increased disability due to stroke                                   2.708661
# mrs 5-6                                                              0.251969
# mrs 0-2                                                              0.397638
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2020
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# count                                                                     956
# age                                                                 73.859833
# male                                                                 0.485356
# infarction                                                           0.848326
# stroke severity                                                       8.92364
# onset-to-arrival time                                                   561.0
# onset known                                                          0.534519
# arrive in 4  hours                                                   0.329498
# precise onset known                                                  0.007322
# onset during sleep                                                   0.004184
# use of AF anticoagulants                                             0.153766
# prior disability                                                     0.410042
# prestroke mrs 0-2                                                    0.926778
# arrival-to-scan time                                                     48.0
# thrombolysis                                                         0.141213
# scan-to-thrombolysis time                                                28.0
# death                                                                0.154812
# discharge disability                                                 2.928042
# increased disability due to stroke                                   2.513228
# mrs 5-6                                                              0.201883
# mrs 0-2                                                              0.439331
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2016 to 2021)  \
# count                                                                             991
# age                                                                         75.355701
# male                                                                         0.525732
# infarction                                                                   0.902119
# stroke severity                                                              7.918264
# onset-to-arrival time                                                           220.0
# onset known                                                                  0.775984
# arrive in 4  hours                                                           0.522704
# precise onset known                                                          0.102926
# onset during sleep                                                           0.082745
# use of AF anticoagulants                                                     0.107972
# prior disability                                                             0.737639
# prestroke mrs 0-2                                                            0.893037
# arrival-to-scan time                                                             35.0
# thrombolysis                                                                 0.173562
# scan-to-thrombolysis time                                                        27.0
# death                                                                        0.088799
# discharge disability                                                         2.303719
# increased disability due to stroke                                           1.565083
# mrs 5-6                                                                      0.133199
# mrs 0-2                                                                      0.628658
# stroke_team                                Invicta Ward Kent and Canterbury Hospital
# year                                                                     2016 to 2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2020)  \
# count                                                                            362
# age                                                                        76.174033
# male                                                                        0.513812
# infarction                                                                  0.944751
# stroke severity                                                             7.607735
# onset-to-arrival time                                                          285.0
# onset known                                                                 0.748619
# arrive in 4  hours                                                          0.461326
# precise onset known                                                         0.038674
# onset during sleep                                                           0.08011
# use of AF anticoagulants                                                    0.124309
# prior disability                                                            0.798343
# prestroke mrs 0-2                                                           0.875691
# arrival-to-scan time                                                            38.0
# thrombolysis                                                                0.143646
# scan-to-thrombolysis time                                                       27.0
# death                                                                       0.069061
# discharge disability                                                        2.179941
# increased disability due to stroke                                          1.374631
# mrs 5-6                                                                     0.121547
# mrs 0-2                                                                     0.621547
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2020
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2021)  \
# count                                                                            629
# age                                                                        74.884738
# male                                                                        0.532591
# infarction                                                                  0.877583
# stroke severity                                                             8.096979
# onset-to-arrival time                                                          193.0
# onset known                                                                 0.791733
# arrive in 4  hours                                                          0.558029
# precise onset known                                                         0.139905
# onset during sleep                                                          0.084261
# use of AF anticoagulants                                                    0.098569
# prior disability                                                            0.702703
# prestroke mrs 0-2                                                           0.903021
# arrival-to-scan time                                                            34.0
# thrombolysis                                                                0.190779
# scan-to-thrombolysis time                                                       27.0
# death                                                                       0.100159
# discharge disability                                                        2.370429
# increased disability due to stroke                                          1.667727
# mrs 5-6                                                                     0.139905
# mrs 0-2                                                                      0.63275
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2021
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# count                                                                             520
# age                                                                         75.711538
# male                                                                         0.553846
# infarction                                                                      0.875
# stroke severity                                                              6.740385
# onset-to-arrival time                                                           257.0
# onset known                                                                       0.8
# arrive in 4  hours                                                           0.471154
# precise onset known                                                          0.276923
# onset during sleep                                                           0.138462
# use of AF anticoagulants                                                     0.132692
# prior disability                                                             1.042308
# prestroke mrs 0-2                                                            0.794231
# arrival-to-scan time                                                             66.0
# thrombolysis                                                                 0.132692
# scan-to-thrombolysis time                                                        45.0
# death                                                                        0.142308
# discharge disability                                                         2.600398
# increased disability due to stroke                                           1.584493
# mrs 5-6                                                                      0.171154
# mrs 0-2                                                                      0.544231
# stroke_team                                University Hospitals Dorset Stroke Service
# year                                                                     2016 to 2021
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# count                                                                            421
# age                                                                        75.564133
# male                                                                        0.539192
# infarction                                                                  0.862233
# stroke severity                                                             6.707838
# onset-to-arrival time                                                          255.0
# onset known                                                                 0.817102
# arrive in 4  hours                                                          0.475059
# precise onset known                                                         0.251781
# onset during sleep                                                          0.133017
# use of AF anticoagulants                                                    0.118765
# prior disability                                                            1.042755
# prestroke mrs 0-2                                                           0.793349
# arrival-to-scan time                                                            72.5
# thrombolysis                                                                0.118765
# scan-to-thrombolysis time                                                       46.5
# death                                                                       0.149644
# discharge disability                                                        2.669136
# increased disability due to stroke                                          1.661728
# mrs 5-6                                                                     0.180523
# mrs 0-2                                                                     0.524941
# stroke_team                               University Hospitals Dorset Stroke Service
# year                                                                            2021
#
#                                    Grange University Hospital (2016 to 2021)  \
# count                                                                    234
# age                                                                73.739316
# male                                                                0.525641
# infarction                                                          0.803419
# stroke severity                                                     7.235043
# onset-to-arrival time                                                  482.5
# onset known                                                         0.688034
# arrive in 4  hours                                                  0.324786
# precise onset known                                                 0.423077
# onset during sleep                                                  0.183761
# use of AF anticoagulants                                            0.098291
# prior disability                                                    0.440171
# prestroke mrs 0-2                                                   0.957265
# arrival-to-scan time                                                    34.0
# thrombolysis                                                        0.145299
# scan-to-thrombolysis time                                               37.5
# death                                                               0.260684
# discharge disability                                                2.209402
# increased disability due to stroke                                  1.769231
# mrs 5-6                                                             0.282051
# mrs 0-2                                                             0.641026
# stroke_team                                       Grange University Hospital
# year                                                            2016 to 2021
#
#                                    Grange University Hospital (2021)
# count                                                            194
# age                                                        73.737113
# male                                                             0.5
# infarction                                                  0.804124
# stroke severity                                             7.247423
# onset-to-arrival time                                          488.0
# onset known                                                 0.695876
# arrive in 4  hours                                          0.345361
# precise onset known                                         0.417526
# onset during sleep                                          0.180412
# use of AF anticoagulants                                    0.097938
# prior disability                                            0.407216
# prestroke mrs 0-2                                           0.963918
# arrival-to-scan time                                            30.0
# thrombolysis                                                0.159794
# scan-to-thrombolysis time                                       34.0
# death                                                       0.262887
# discharge disability                                        2.175258
# increased disability due to stroke                          1.768041
# mrs 5-6                                                     0.278351
# mrs 0-2                                                     0.639175
# stroke_team                               Grange University Hospital
# year                                                            2021
#
# [23 rows x 805 columns]

# %%
summary_stats_df.round(3).to_csv('summary_stats.csv')

# %% [markdown]
# ## Limit analysis to arrival in 4 hours

# %%
mask = data_all['arrive in 4  hours'] == True
data_4hr = data_all[mask]

# %% [markdown]
# Add onset to thrombolysis

# %%
data_4hr['onset to thrombolysis'] = (
    data_4hr['onset-to-arrival time'] + 
    data_4hr['arrival-to-scan time'] + 
    data_4hr['scan-to-thrombolysis time'])
# Out:
# /tmp/ipykernel_40557/3194208934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_4hr['onset to thrombolysis'] = (

# %%
# Repeat analysis for patients arriving in 4 hours
summary_stats_4hr = dict()
for year in [all_years_str] + years_covered:
    if year == all_years_str:
        data = data_4hr
    else:
        data = data_4hr[(
            (data_4hr['year'] == year)
            )]
    results = dict()
    for k, v in summary_stats_dict.items():
        if v == 'mean':
            results[k] = data[k].mean()
        elif v == 'median':
            results[k] = data[k].median()
        elif v == 'sum':
            results[k] = data[k].sum()
    results['stroke_team'] = 'all E+W'
    results['year'] = year
    summary_stats_4hr[f'all E+W ({year})'] = results

for hospital in sw:
    for year in [all_years_str] + years_covered:
        if year == all_years_str:
            data = data_4hr[data_4hr['stroke team'] == hospital]
        else:
            data = data_4hr[(
                (data_4hr['stroke team'] == hospital) &
                (data_4hr['year'] == year)
                )]
        # data = data_4hr[data_4hr['stroke team'] == hospital]
        results = dict()
        for k, v in summary_stats_dict.items():
            if v == 'mean':
                results[k] = data[k].mean()
            elif v == 'median':
                results[k] = data[k].median()
            elif v == 'sum':
                results[k] = data[k].sum()
        results['stroke_team'] = hospital
        results['year'] = year
        summary_stats_4hr[f'{hospital} ({year})'] = results

summary_stats_4hr_df = pd.DataFrame(summary_stats_4hr)

# Only keep hospitals with more than 100 admissions
# in the full data (not the 4hr data) - same mask as earlier.
summary_stats_4hr_df = summary_stats_4hr_df.T[mask_count].T


summary_stats_4hr_df = summary_stats_4hr_df.round(3)
# summary_stats_4hr_df.rename(sw_dic, axis=1, inplace = True)
summary_stats_4hr_df
# Out:
#                                    all E+W (2016 to 2021) all E+W (2016)  \
# count                                              124047          20704
# age                                             75.124691      75.416103
# male                                             0.521198       0.512268
# infarction                                       0.848622       0.849787
# stroke severity                                  9.331439       9.396783
# onset-to-arrival time                               104.0           97.0
# onset known                                           1.0            1.0
# arrive in 4  hours                                    1.0            1.0
# precise onset known                                0.6296       0.630313
# onset during sleep                                 0.0467       0.044484
# use of AF anticoagulants                         0.140963       0.104859
# prior disability                                 1.099607       1.092832
# prestroke mrs 0-2                                0.788491       0.783568
# arrival-to-scan time                                 26.0           29.0
# thrombolysis                                     0.298677       0.294532
# scan-to-thrombolysis time                            30.0           30.0
# death                                            0.183576       0.191267
# discharge disability                             2.920277        2.94983
# increased disability due to stroke               1.819181       1.854258
# mrs 5-6                                          0.250623       0.260867
# mrs 0-2                                          0.465533       0.453729
# stroke_team                                       all E+W        all E+W
# year                                         2016 to 2021           2016
#
#                                    all E+W (2017) all E+W (2018)  \
# count                                       21090          20580
# age                                     75.287577      75.289116
# male                                      0.51138       0.520943
# infarction                               0.852916       0.850049
# stroke severity                          9.440066       9.447328
# onset-to-arrival time                       100.0          103.0
# onset known                                   1.0            1.0
# arrive in 4  hours                            1.0            1.0
# precise onset known                      0.640778       0.637658
# onset during sleep                        0.04642       0.048105
# use of AF anticoagulants                 0.115932       0.147473
# prior disability                         1.089853        1.12896
# prestroke mrs 0-2                        0.790754       0.781681
# arrival-to-scan time                         26.0           26.0
# thrombolysis                             0.299621       0.302964
# scan-to-thrombolysis time                    30.0           29.0
# death                                    0.186534       0.183625
# discharge disability                     2.900865       2.913568
# increased disability due to stroke       1.808805       1.784066
# mrs 5-6                                   0.25358       0.253936
# mrs 0-2                                  0.471029       0.465549
# stroke_team                               all E+W        all E+W
# year                                         2017           2018
#
#                                    all E+W (2019) all E+W (2020)  \
# count                                       20686          20086
# age                                     75.269506      74.657722
# male                                     0.524799       0.526685
# infarction                               0.844823        0.84656
# stroke severity                          9.420526       9.202031
# onset-to-arrival time                       104.0          105.0
# onset known                                   1.0            1.0
# arrive in 4  hours                            1.0            1.0
# precise onset known                      0.632457       0.621079
# onset during sleep                       0.045635       0.050433
# use of AF anticoagulants                 0.155999       0.157971
# prior disability                         1.123949       1.067808
# prestroke mrs 0-2                        0.781736       0.797919
# arrival-to-scan time                         26.0           26.0
# thrombolysis                             0.306826        0.29304
# scan-to-thrombolysis time                    30.0           32.0
# death                                    0.192256       0.174251
# discharge disability                     2.943787       2.879904
# increased disability due to stroke       1.817624       1.811241
# mrs 5-6                                  0.255245       0.238325
# mrs 0-2                                  0.466016        0.47212
# stroke_team                               all E+W        all E+W
# year                                         2019           2020
#
#                                    all E+W (2021)  \
# count                                       20901
# age                                       74.8152
# male                                     0.531362
# infarction                               0.847471
# stroke severity                          9.079183
# onset-to-arrival time                       113.0
# onset known                                   1.0
# arrive in 4  hours                            1.0
# precise onset known                      0.615042
# onset during sleep                       0.045261
# use of AF anticoagulants                 0.164346
# prior disability                         1.093728
# prestroke mrs 0-2                        0.795416
# arrival-to-scan time                         25.0
# thrombolysis                             0.294962
# scan-to-thrombolysis time                    32.0
# death                                    0.173293
# discharge disability                     2.932637
# increased disability due to stroke        1.83857
# mrs 5-6                                  0.241472
# mrs 0-2                                  0.464858
# stroke_team                               all E+W
# year                                         2021
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016 to 2021)  \
# count                                                                             973
# age                                                                         73.702467
# male                                                                         0.527235
# infarction                                                                   0.840699
# stroke severity                                                              8.526208
# onset-to-arrival time                                                           110.0
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.736896
# onset during sleep                                                           0.055498
# use of AF anticoagulants                                                     0.109969
# prior disability                                                             1.121274
# prestroke mrs 0-2                                                             0.79445
# arrival-to-scan time                                                             20.0
# thrombolysis                                                                 0.295992
# scan-to-thrombolysis time                                                        23.0
# death                                                                        0.172662
# discharge disability                                                         2.803516
# increased disability due to stroke                                           1.682523
# mrs 5-6                                                                      0.238438
# mrs 0-2                                                                      0.517986
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                     2016 to 2021
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016)  \
# count                                                                             184
# age                                                                         74.565217
# male                                                                         0.565217
# infarction                                                                   0.798913
# stroke severity                                                              8.429348
# onset-to-arrival time                                                           104.5
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.766304
# onset during sleep                                                           0.070652
# use of AF anticoagulants                                                     0.070652
# prior disability                                                             1.119565
# prestroke mrs 0-2                                                            0.809783
# arrival-to-scan time                                                             17.0
# thrombolysis                                                                 0.304348
# scan-to-thrombolysis time                                                        20.0
# death                                                                        0.157609
# discharge disability                                                         2.793478
# increased disability due to stroke                                           1.673913
# mrs 5-6                                                                      0.211957
# mrs 0-2                                                                      0.494565
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                             2016
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2017)  \
# count                                                                             144
# age                                                                         74.409722
# male                                                                         0.548611
# infarction                                                                   0.847222
# stroke severity                                                              8.729167
# onset-to-arrival time                                                           111.0
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.652778
# onset during sleep                                                           0.097222
# use of AF anticoagulants                                                     0.090278
# prior disability                                                             1.076389
# prestroke mrs 0-2                                                            0.833333
# arrival-to-scan time                                                             19.5
# thrombolysis                                                                 0.243056
# scan-to-thrombolysis time                                                        29.0
# death                                                                        0.166667
# discharge disability                                                          2.86014
# increased disability due to stroke                                           1.783217
# mrs 5-6                                                                      0.270833
# mrs 0-2                                                                      0.493056
# stroke_team                         Northumbria Specialist Emergency Care Hospital...
# year                                                                             2017
#
#                                     ...  \
# count                               ...
# age                                 ...
# male                                ...
# infarction                          ...
# stroke severity                     ...
# onset-to-arrival time               ...
# onset known                         ...
# arrive in 4  hours                  ...
# precise onset known                 ...
# onset during sleep                  ...
# use of AF anticoagulants            ...
# prior disability                    ...
# prestroke mrs 0-2                   ...
# arrival-to-scan time                ...
# thrombolysis                        ...
# scan-to-thrombolysis time           ...
# death                               ...
# discharge disability                ...
# increased disability due to stroke  ...
# mrs 5-6                             ...
# mrs 0-2                             ...
# stroke_team                         ...
# year                                ...
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# count                                                                             457
# age                                                                         73.561269
# male                                                                         0.501094
# infarction                                                                   0.873085
# stroke severity                                                             10.553611
# onset-to-arrival time                                                           109.0
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.043764
# onset during sleep                                                           0.004376
# use of AF anticoagulants                                                     0.113786
# prior disability                                                             0.512035
# prestroke mrs 0-2                                                            0.905908
# arrival-to-scan time                                                             30.0
# thrombolysis                                                                 0.343545
# scan-to-thrombolysis time                                                        30.0
# death                                                                        0.183807
# discharge disability                                                         3.191209
# increased disability due to stroke                                           2.676923
# mrs 5-6                                                                      0.242888
# mrs 0-2                                                                      0.376368
# stroke_team                                       Queen's Medical Centre - Nottingham
# year                                                                     2016 to 2021
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# count                                                                     132
# age                                                                 72.954545
# male                                                                      0.5
# infarction                                                           0.909091
# stroke severity                                                      9.522727
# onset-to-arrival time                                                   115.5
# onset known                                                               1.0
# arrive in 4  hours                                                        1.0
# precise onset known                                                  0.030303
# onset during sleep                                                        0.0
# use of AF anticoagulants                                             0.106061
# prior disability                                                     0.590909
# prestroke mrs 0-2                                                    0.893939
# arrival-to-scan time                                                     28.5
# thrombolysis                                                         0.363636
# scan-to-thrombolysis time                                                30.0
# death                                                                0.189394
# discharge disability                                                 3.106061
# increased disability due to stroke                                   2.515152
# mrs 5-6                                                              0.242424
# mrs 0-2                                                              0.416667
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2020
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# count                                                                     315
# age                                                                 74.214286
# male                                                                 0.492063
# infarction                                                           0.863492
# stroke severity                                                     10.968254
# onset-to-arrival time                                                   103.0
# onset known                                                               1.0
# arrive in 4  hours                                                        1.0
# precise onset known                                                  0.022222
# onset during sleep                                                   0.006349
# use of AF anticoagulants                                             0.120635
# prior disability                                                     0.495238
# prestroke mrs 0-2                                                    0.907937
# arrival-to-scan time                                                     32.0
# thrombolysis                                                         0.326984
# scan-to-thrombolysis time                                                31.0
# death                                                                0.177778
# discharge disability                                                 3.182109
# increased disability due to stroke                                   2.683706
# mrs 5-6                                                               0.24127
# mrs 0-2                                                              0.371429
# stroke_team                               Queen's Medical Centre - Nottingham
# year                                                                     2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2016 to 2021)  \
# count                                                                             518
# age                                                                         75.405405
# male                                                                          0.53861
# infarction                                                                   0.901544
# stroke severity                                                              8.862934
# onset-to-arrival time                                                           115.0
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.162162
# onset during sleep                                                            0.03861
# use of AF anticoagulants                                                     0.104247
# prior disability                                                             0.683398
# prestroke mrs 0-2                                                            0.905405
# arrival-to-scan time                                                             33.0
# thrombolysis                                                                 0.281853
# scan-to-thrombolysis time                                                        25.0
# death                                                                        0.104247
# discharge disability                                                         2.322134
# increased disability due to stroke                                           1.634387
# mrs 5-6                                                                       0.15444
# mrs 0-2                                                                      0.640927
# stroke_team                                Invicta Ward Kent and Canterbury Hospital
# year                                                                     2016 to 2021
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2020)  \
# count                                                                            167
# age                                                                        75.494012
# male                                                                         0.57485
# infarction                                                                  0.934132
# stroke severity                                                             8.610778
# onset-to-arrival time                                                          115.0
# onset known                                                                      1.0
# arrive in 4  hours                                                               1.0
# precise onset known                                                         0.083832
# onset during sleep                                                           0.05988
# use of AF anticoagulants                                                    0.143713
# prior disability                                                            0.562874
# prestroke mrs 0-2                                                           0.922156
# arrival-to-scan time                                                            32.0
# thrombolysis                                                                0.263473
# scan-to-thrombolysis time                                                       25.5
# death                                                                       0.077844
# discharge disability                                                        2.122581
# increased disability due to stroke                                          1.554839
# mrs 5-6                                                                     0.137725
# mrs 0-2                                                                     0.670659
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2020
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2021)  \
# count                                                                            351
# age                                                                        75.363248
# male                                                                        0.521368
# infarction                                                                   0.88604
# stroke severity                                                             8.982906
# onset-to-arrival time                                                          115.0
# onset known                                                                      1.0
# arrive in 4  hours                                                               1.0
# precise onset known                                                          0.19943
# onset during sleep                                                           0.02849
# use of AF anticoagulants                                                     0.08547
# prior disability                                                            0.740741
# prestroke mrs 0-2                                                           0.897436
# arrival-to-scan time                                                            33.0
# thrombolysis                                                                0.290598
# scan-to-thrombolysis time                                                       25.0
# death                                                                       0.116809
# discharge disability                                                        2.410256
# increased disability due to stroke                                          1.669516
# mrs 5-6                                                                     0.162393
# mrs 0-2                                                                     0.626781
# stroke_team                               Invicta Ward Kent and Canterbury Hospital
# year                                                                            2021
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# count                                                                             245
# age                                                                         75.908163
# male                                                                         0.522449
# infarction                                                                    0.84898
# stroke severity                                                              8.273469
# onset-to-arrival time                                                           120.0
# onset known                                                                       1.0
# arrive in 4  hours                                                                1.0
# precise onset known                                                          0.497959
# onset during sleep                                                           0.073469
# use of AF anticoagulants                                                     0.138776
# prior disability                                                             1.016327
# prestroke mrs 0-2                                                            0.791837
# arrival-to-scan time                                                             17.0
# thrombolysis                                                                 0.277551
# scan-to-thrombolysis time                                                        45.0
# death                                                                        0.187755
# discharge disability                                                          2.81405
# increased disability due to stroke                                            1.81405
# mrs 5-6                                                                      0.232653
# mrs 0-2                                                                      0.502041
# stroke_team                                University Hospitals Dorset Stroke Service
# year                                                                     2016 to 2021
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# count                                                                            200
# age                                                                            75.95
# male                                                                           0.515
# infarction                                                                     0.835
# stroke severity                                                                8.285
# onset-to-arrival time                                                          120.0
# onset known                                                                      1.0
# arrive in 4  hours                                                               1.0
# precise onset known                                                             0.46
# onset during sleep                                                              0.08
# use of AF anticoagulants                                                        0.12
# prior disability                                                                0.99
# prestroke mrs 0-2                                                                0.8
# arrival-to-scan time                                                            20.0
# thrombolysis                                                                    0.25
# scan-to-thrombolysis time                                                       46.5
# death                                                                            0.2
# discharge disability                                                        2.908629
# increased disability due to stroke                                          1.939086
# mrs 5-6                                                                         0.25
# mrs 0-2                                                                        0.475
# stroke_team                               University Hospitals Dorset Stroke Service
# year                                                                            2021
#
#                                    Grange University Hospital (2016 to 2021)  \
# count                                                                     76
# age                                                                     72.5
# male                                                                0.578947
# infarction                                                          0.776316
# stroke severity                                                     9.144737
# onset-to-arrival time                                                  151.0
# onset known                                                              1.0
# arrive in 4  hours                                                       1.0
# precise onset known                                                 0.763158
# onset during sleep                                                       0.0
# use of AF anticoagulants                                            0.052632
# prior disability                                                    0.486842
# prestroke mrs 0-2                                                   0.934211
# arrival-to-scan time                                                    24.0
# thrombolysis                                                        0.447368
# scan-to-thrombolysis time                                               37.5
# death                                                               0.276316
# discharge disability                                                    2.25
# increased disability due to stroke                                  1.763158
# mrs 5-6                                                             0.276316
# mrs 0-2                                                             0.618421
# stroke_team                                       Grange University Hospital
# year                                                            2016 to 2021
#
#                                    Grange University Hospital (2021)
# count                                                             67
# age                                                        72.873134
# male                                                         0.58209
# infarction                                                  0.761194
# stroke severity                                             9.507463
# onset-to-arrival time                                          150.0
# onset known                                                      1.0
# arrive in 4  hours                                               1.0
# precise onset known                                         0.761194
# onset during sleep                                               0.0
# use of AF anticoagulants                                    0.059701
# prior disability                                            0.447761
# prestroke mrs 0-2                                           0.940299
# arrival-to-scan time                                            22.0
# thrombolysis                                                0.462687
# scan-to-thrombolysis time                                       34.0
# death                                                       0.283582
# discharge disability                                        2.298507
# increased disability due to stroke                          1.850746
# mrs 5-6                                                     0.283582
# mrs 0-2                                                      0.61194
# stroke_team                               Grange University Hospital
# year                                                            2021
#
# [23 rows x 805 columns]

# %%
summary_stats_4hr_df.round(3).to_csv('summary_stats_4hr.csv')

# %%
rows = [
    'age', 'infarction', 'precise onset known', 'onset during sleep',
    'use of AF anticoagulants', 'prior disability', 'prestroke mrs 0-2', 
    'stroke severity',
    'onset-to-arrival time', 'arrival-to-scan time', 'thrombolysis',
    'scan-to-thrombolysis time', 'discharge disability', 'death',
    'increased disability due to stroke', 'mrs 5-6', 'mrs 0-2'
]

for row in rows:
    key_results[row] = summary_stats_4hr_df.loc[row]

# %%
key_results = key_results.round(3).T

# %%
key_results
# Out:
#                                    all E+W (2016 to 2021) all E+W (2016)  \
# onset known                                      0.705057       0.694567
# arrive in 4 hours                                0.436868       0.450822
# thrombolysis all arrivals                        0.134022         0.1357
# age                                             75.124691      75.416103
# infarction                                       0.848622       0.849787
# precise onset known                                0.6296       0.630313
# onset during sleep                                 0.0467       0.044484
# use of AF anticoagulants                         0.140963       0.104859
# prior disability                                 1.099607       1.092832
# prestroke mrs 0-2                                0.788491       0.783568
# stroke severity                                  9.331439       9.396783
# onset-to-arrival time                               104.0           97.0
# arrival-to-scan time                                 26.0           29.0
# thrombolysis                                     0.298677       0.294532
# scan-to-thrombolysis time                            30.0           30.0
# discharge disability                             2.920277        2.94983
# death                                            0.183576       0.191267
# increased disability due to stroke               1.819181       1.854258
# mrs 5-6                                          0.250623       0.260867
# mrs 0-2                                          0.465533       0.453729
#
#                                    all E+W (2017) all E+W (2018)  \
# onset known                              0.694941       0.706786
# arrive in 4 hours                        0.447343       0.446063
# thrombolysis all arrivals                0.136727       0.138024
# age                                     75.287577      75.289116
# infarction                               0.852916       0.850049
# precise onset known                      0.640778       0.637658
# onset during sleep                        0.04642       0.048105
# use of AF anticoagulants                 0.115932       0.147473
# prior disability                         1.089853        1.12896
# prestroke mrs 0-2                        0.790754       0.781681
# stroke severity                          9.440066       9.447328
# onset-to-arrival time                       100.0          103.0
# arrival-to-scan time                         26.0           26.0
# thrombolysis                             0.299621       0.302964
# scan-to-thrombolysis time                    30.0           29.0
# discharge disability                     2.900865       2.913568
# death                                    0.186534       0.183625
# increased disability due to stroke       1.808805       1.784066
# mrs 5-6                                   0.25358       0.253936
# mrs 0-2                                  0.471029       0.465549
#
#                                    all E+W (2019) all E+W (2020)  \
# onset known                              0.718975        0.70714
# arrive in 4 hours                        0.442075       0.425335
# thrombolysis all arrivals                0.139743       0.128621
# age                                     75.269506      74.657722
# infarction                               0.844823        0.84656
# precise onset known                      0.632457       0.621079
# onset during sleep                       0.045635       0.050433
# use of AF anticoagulants                 0.155999       0.157971
# prior disability                         1.123949       1.067808
# prestroke mrs 0-2                        0.781736       0.797919
# stroke severity                          9.420526       9.202031
# onset-to-arrival time                       104.0          105.0
# arrival-to-scan time                         26.0           26.0
# thrombolysis                             0.306826        0.29304
# scan-to-thrombolysis time                    30.0           32.0
# discharge disability                     2.943787       2.879904
# death                                    0.192256       0.174251
# increased disability due to stroke       1.817624       1.811241
# mrs 5-6                                  0.255245       0.238325
# mrs 0-2                                  0.466016        0.47212
#
#                                    all E+W (2021)  \
# onset known                              0.707602
# arrive in 4 hours                         0.41207
# thrombolysis all arrivals                0.126099
# age                                       74.8152
# infarction                               0.847471
# precise onset known                      0.615042
# onset during sleep                       0.045261
# use of AF anticoagulants                 0.164346
# prior disability                         1.093728
# prestroke mrs 0-2                        0.795416
# stroke severity                          9.079183
# onset-to-arrival time                       113.0
# arrival-to-scan time                         25.0
# thrombolysis                             0.294962
# scan-to-thrombolysis time                    32.0
# discharge disability                     2.932637
# death                                    0.173293
# increased disability due to stroke        1.83857
# mrs 5-6                                  0.241472
# mrs 0-2                                  0.464858
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016 to 2021)  \
# onset known                                                                  0.807393
# arrive in 4 hours                                                            0.473249
# thrombolysis all arrivals                                                     0.14251
# age                                                                         73.702467
# infarction                                                                   0.840699
# precise onset known                                                          0.736896
# onset during sleep                                                           0.055498
# use of AF anticoagulants                                                     0.109969
# prior disability                                                             1.121274
# prestroke mrs 0-2                                                             0.79445
# stroke severity                                                              8.526208
# onset-to-arrival time                                                           110.0
# arrival-to-scan time                                                             20.0
# thrombolysis                                                                 0.295992
# scan-to-thrombolysis time                                                        23.0
# discharge disability                                                         2.803516
# death                                                                        0.172662
# increased disability due to stroke                                           1.682523
# mrs 5-6                                                                      0.238438
# mrs 0-2                                                                      0.517986
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2016)  \
# onset known                                                                  0.799486
# arrive in 4 hours                                                            0.473008
# thrombolysis all arrivals                                                     0.14653
# age                                                                         74.565217
# infarction                                                                   0.798913
# precise onset known                                                          0.766304
# onset during sleep                                                           0.070652
# use of AF anticoagulants                                                     0.070652
# prior disability                                                             1.119565
# prestroke mrs 0-2                                                            0.809783
# stroke severity                                                              8.429348
# onset-to-arrival time                                                           104.5
# arrival-to-scan time                                                             17.0
# thrombolysis                                                                 0.304348
# scan-to-thrombolysis time                                                        20.0
# discharge disability                                                         2.793478
# death                                                                        0.157609
# increased disability due to stroke                                           1.673913
# mrs 5-6                                                                      0.211957
# mrs 0-2                                                                      0.494565
#
#                                    Northumbria Specialist Emergency Care Hospital HASU (2017)  \
# onset known                                                                  0.786408
# arrive in 4 hours                                                            0.466019
# thrombolysis all arrivals                                                    0.113269
# age                                                                         74.409722
# infarction                                                                   0.847222
# precise onset known                                                          0.652778
# onset during sleep                                                           0.097222
# use of AF anticoagulants                                                     0.090278
# prior disability                                                             1.076389
# prestroke mrs 0-2                                                            0.833333
# stroke severity                                                              8.729167
# onset-to-arrival time                                                           111.0
# arrival-to-scan time                                                             19.5
# thrombolysis                                                                 0.243056
# scan-to-thrombolysis time                                                        29.0
# discharge disability                                                          2.86014
# death                                                                        0.166667
# increased disability due to stroke                                           1.783217
# mrs 5-6                                                                      0.270833
# mrs 0-2                                                                      0.493056
#
#                                     ...  \
# onset known                         ...
# arrive in 4 hours                   ...
# thrombolysis all arrivals           ...
# age                                 ...
# infarction                          ...
# precise onset known                 ...
# onset during sleep                  ...
# use of AF anticoagulants            ...
# prior disability                    ...
# prestroke mrs 0-2                   ...
# stroke severity                     ...
# onset-to-arrival time               ...
# arrival-to-scan time                ...
# thrombolysis                        ...
# scan-to-thrombolysis time           ...
# discharge disability                ...
# death                               ...
# increased disability due to stroke  ...
# mrs 5-6                             ...
# mrs 0-2                             ...
#
#                                    Queen's Medical Centre - Nottingham (2016 to 2021)  \
# onset known                                                                  0.574468
# arrive in 4 hours                                                            0.373977
# thrombolysis all arrivals                                                    0.157119
# age                                                                         73.561269
# infarction                                                                   0.873085
# precise onset known                                                          0.043764
# onset during sleep                                                           0.004376
# use of AF anticoagulants                                                     0.113786
# prior disability                                                             0.512035
# prestroke mrs 0-2                                                            0.905908
# stroke severity                                                             10.553611
# onset-to-arrival time                                                           109.0
# arrival-to-scan time                                                             30.0
# thrombolysis                                                                 0.343545
# scan-to-thrombolysis time                                                        30.0
# discharge disability                                                         3.191209
# death                                                                        0.183807
# increased disability due to stroke                                           2.676923
# mrs 5-6                                                                      0.242888
# mrs 0-2                                                                      0.376368
#
#                                    Queen's Medical Centre - Nottingham (2020)  \
# onset known                                                          0.708661
# arrive in 4 hours                                                    0.519685
# thrombolysis all arrivals                                            0.200787
# age                                                                 72.954545
# infarction                                                           0.909091
# precise onset known                                                  0.030303
# onset during sleep                                                        0.0
# use of AF anticoagulants                                             0.106061
# prior disability                                                     0.590909
# prestroke mrs 0-2                                                    0.893939
# stroke severity                                                      9.522727
# onset-to-arrival time                                                   115.5
# arrival-to-scan time                                                     28.5
# thrombolysis                                                         0.363636
# scan-to-thrombolysis time                                                30.0
# discharge disability                                                 3.106061
# death                                                                0.189394
# increased disability due to stroke                                   2.515152
# mrs 5-6                                                              0.242424
# mrs 0-2                                                              0.416667
#
#                                    Queen's Medical Centre - Nottingham (2021)  \
# onset known                                                          0.534519
# arrive in 4 hours                                                    0.329498
# thrombolysis all arrivals                                            0.141213
# age                                                                 74.214286
# infarction                                                           0.863492
# precise onset known                                                  0.022222
# onset during sleep                                                   0.006349
# use of AF anticoagulants                                             0.120635
# prior disability                                                     0.495238
# prestroke mrs 0-2                                                    0.907937
# stroke severity                                                     10.968254
# onset-to-arrival time                                                   103.0
# arrival-to-scan time                                                     32.0
# thrombolysis                                                         0.326984
# scan-to-thrombolysis time                                                31.0
# discharge disability                                                 3.182109
# death                                                                0.177778
# increased disability due to stroke                                   2.683706
# mrs 5-6                                                               0.24127
# mrs 0-2                                                              0.371429
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2016 to 2021)  \
# onset known                                                                  0.775984
# arrive in 4 hours                                                            0.522704
# thrombolysis all arrivals                                                    0.173562
# age                                                                         75.405405
# infarction                                                                   0.901544
# precise onset known                                                          0.162162
# onset during sleep                                                            0.03861
# use of AF anticoagulants                                                     0.104247
# prior disability                                                             0.683398
# prestroke mrs 0-2                                                            0.905405
# stroke severity                                                              8.862934
# onset-to-arrival time                                                           115.0
# arrival-to-scan time                                                             33.0
# thrombolysis                                                                 0.281853
# scan-to-thrombolysis time                                                        25.0
# discharge disability                                                         2.322134
# death                                                                        0.104247
# increased disability due to stroke                                           1.634387
# mrs 5-6                                                                       0.15444
# mrs 0-2                                                                      0.640927
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2020)  \
# onset known                                                                 0.748619
# arrive in 4 hours                                                           0.461326
# thrombolysis all arrivals                                                   0.143646
# age                                                                        75.494012
# infarction                                                                  0.934132
# precise onset known                                                         0.083832
# onset during sleep                                                           0.05988
# use of AF anticoagulants                                                    0.143713
# prior disability                                                            0.562874
# prestroke mrs 0-2                                                           0.922156
# stroke severity                                                             8.610778
# onset-to-arrival time                                                          115.0
# arrival-to-scan time                                                            32.0
# thrombolysis                                                                0.263473
# scan-to-thrombolysis time                                                       25.5
# discharge disability                                                        2.122581
# death                                                                       0.077844
# increased disability due to stroke                                          1.554839
# mrs 5-6                                                                     0.137725
# mrs 0-2                                                                     0.670659
#
#                                    Invicta Ward Kent and Canterbury Hospital  (2021)  \
# onset known                                                                 0.791733
# arrive in 4 hours                                                           0.558029
# thrombolysis all arrivals                                                   0.190779
# age                                                                        75.363248
# infarction                                                                   0.88604
# precise onset known                                                          0.19943
# onset during sleep                                                           0.02849
# use of AF anticoagulants                                                     0.08547
# prior disability                                                            0.740741
# prestroke mrs 0-2                                                           0.897436
# stroke severity                                                             8.982906
# onset-to-arrival time                                                          115.0
# arrival-to-scan time                                                            33.0
# thrombolysis                                                                0.290598
# scan-to-thrombolysis time                                                       25.0
# discharge disability                                                        2.410256
# death                                                                       0.116809
# increased disability due to stroke                                          1.669516
# mrs 5-6                                                                     0.162393
# mrs 0-2                                                                     0.626781
#
#                                    University Hospitals Dorset Stroke Service (2016 to 2021)  \
# onset known                                                                       0.8
# arrive in 4 hours                                                            0.471154
# thrombolysis all arrivals                                                    0.132692
# age                                                                         75.908163
# infarction                                                                    0.84898
# precise onset known                                                          0.497959
# onset during sleep                                                           0.073469
# use of AF anticoagulants                                                     0.138776
# prior disability                                                             1.016327
# prestroke mrs 0-2                                                            0.791837
# stroke severity                                                              8.273469
# onset-to-arrival time                                                           120.0
# arrival-to-scan time                                                             17.0
# thrombolysis                                                                 0.277551
# scan-to-thrombolysis time                                                        45.0
# discharge disability                                                          2.81405
# death                                                                        0.187755
# increased disability due to stroke                                            1.81405
# mrs 5-6                                                                      0.232653
# mrs 0-2                                                                      0.502041
#
#                                    University Hospitals Dorset Stroke Service (2021)  \
# onset known                                                                 0.817102
# arrive in 4 hours                                                           0.475059
# thrombolysis all arrivals                                                   0.118765
# age                                                                            75.95
# infarction                                                                     0.835
# precise onset known                                                             0.46
# onset during sleep                                                              0.08
# use of AF anticoagulants                                                        0.12
# prior disability                                                                0.99
# prestroke mrs 0-2                                                                0.8
# stroke severity                                                                8.285
# onset-to-arrival time                                                          120.0
# arrival-to-scan time                                                            20.0
# thrombolysis                                                                    0.25
# scan-to-thrombolysis time                                                       46.5
# discharge disability                                                        2.908629
# death                                                                            0.2
# increased disability due to stroke                                          1.939086
# mrs 5-6                                                                         0.25
# mrs 0-2                                                                        0.475
#
#                                    Grange University Hospital (2016 to 2021)  \
# onset known                                                         0.688034
# arrive in 4 hours                                                   0.324786
# thrombolysis all arrivals                                           0.145299
# age                                                                     72.5
# infarction                                                          0.776316
# precise onset known                                                 0.763158
# onset during sleep                                                       0.0
# use of AF anticoagulants                                            0.052632
# prior disability                                                    0.486842
# prestroke mrs 0-2                                                   0.934211
# stroke severity                                                     9.144737
# onset-to-arrival time                                                  151.0
# arrival-to-scan time                                                    24.0
# thrombolysis                                                        0.447368
# scan-to-thrombolysis time                                               37.5
# discharge disability                                                    2.25
# death                                                               0.276316
# increased disability due to stroke                                  1.763158
# mrs 5-6                                                             0.276316
# mrs 0-2                                                             0.618421
#
#                                    Grange University Hospital (2021)
# onset known                                                 0.695876
# arrive in 4 hours                                           0.345361
# thrombolysis all arrivals                                   0.159794
# age                                                        72.873134
# infarction                                                  0.761194
# precise onset known                                         0.761194
# onset during sleep                                               0.0
# use of AF anticoagulants                                    0.059701
# prior disability                                            0.447761
# prestroke mrs 0-2                                           0.940299
# stroke severity                                             9.507463
# onset-to-arrival time                                          150.0
# arrival-to-scan time                                            22.0
# thrombolysis                                                0.462687
# scan-to-thrombolysis time                                       34.0
# discharge disability                                        2.298507
# death                                                       0.283582
# increased disability due to stroke                          1.850746
# mrs 5-6                                                     0.283582
# mrs 0-2                                                      0.61194
#
# [20 rows x 805 columns]
